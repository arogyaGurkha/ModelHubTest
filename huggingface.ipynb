# %%
from dotenv import dotenv_values

hf_token = dotenv_values(".env")['HF_TOKEN']

# %%
from huggingface_hub import HfApi, list_models

# Or configure a HfApi client
hf_api = HfApi(
    endpoint="https://huggingface.co", # Can be a Private Hub endpoint.
    token=hf_token, # Token is not persisted on the machine.
)
# models = hf_api.list_models()

# %%
import pandas as pd

df = pd.DataFrame(models)

# save to csv and pkl
df.to_csv("models.csv")
df.to_pickle("models.pkl")

# %%
import pandas as pd

data = pd.read_pickle("models.pkl")
data
# Out:
#                                           id author   sha  \
# 0                      albert/albert-base-v1   None  None
# 1                      albert/albert-base-v2   None  None
# 2                     albert/albert-large-v1   None  None
# 3                     albert/albert-large-v2   None  None
# 4                    albert/albert-xlarge-v1   None  None
# ...                                      ...    ...   ...
# 601169   vyto-keto-gummies/vyto-keto-gummies   None  None
# 601170  elrosech/my_awesome_opus_books_model   None  None
# 601171          DavidAU/BrainDerp2-Q6_K-GGUF   None  None
# 601172   jonknownothing/sdxl-lora-advanced-1   None  None
# 601173                 HarikaR/German_intent   None  None
#
#                       created_at last_modified  private gated disabled  \
# 0      2022-03-02 23:29:04+00:00          None    False  None     None
# 1      2022-03-02 23:29:04+00:00          None    False  None     None
# 2      2022-03-02 23:29:04+00:00          None    False  None     None
# 3      2022-03-02 23:29:04+00:00          None    False  None     None
# 4      2022-03-02 23:29:04+00:00          None    False  None     None
# ...                          ...           ...      ...   ...      ...
# 601169 2024-04-15 04:46:02+00:00          None    False  None     None
# 601170 2024-04-15 04:46:20+00:00          None    False  None     None
# 601171 2024-04-15 04:46:38+00:00          None    False  None     None
# 601172 2024-04-15 04:46:56+00:00          None    False  None     None
# 601173 2024-04-15 04:47:59+00:00          None    False  None     None
#
#         downloads  likes  ...          pipeline_tag mask_token card_data  \
# 0           15728      6  ...             fill-mask       None      None
# 1         2620588     88  ...             fill-mask       None      None
# 2            1564      2  ...             fill-mask       None      None
# 3          361858     13  ...             fill-mask       None      None
# 4            1161      3  ...             fill-mask       None      None
# ...           ...    ...  ...                   ...        ...       ...
# 601169          0      0  ...                  None       None      None
# 601170          0      0  ...  text2text-generation       None      None
# 601171          0      0  ...                  None       None      None
# 601172          0      0  ...                  None       None      None
# 601173          0      0  ...                  None       None      None
#
#        widget_data model_index config transformers_info siblings spaces  \
# 0             None        None   None              None     None   None
# 1             None        None   None              None     None   None
# 2             None        None   None              None     None   None
# 3             None        None   None              None     None   None
# 4             None        None   None              None     None   None
# ...            ...         ...    ...               ...      ...    ...
# 601169        None        None   None              None     None   None
# 601170        None        None   None              None     None   None
# 601171        None        None   None              None     None   None
# 601172        None        None   None              None     None   None
# 601173        None        None   None              None     None   None
#
#        safetensors
# 0             None
# 1             None
# 2             None
# 3             None
# 4             None
# ...            ...
# 601169        None
# 601170        None
# 601171        None
# 601172        None
# 601173        None
#
# [601174 rows x 22 columns]

# %%
# Get models based on datasets
from huggingface_hub import ModelFilter
datasets = hf_api.list_models(filter="squad")
for dataset in datasets:
    print(dataset)
    break
# Out:
# ModelInfo(id='Shavrina/RusEnQA', author='Shavrina', sha='4f3582e6af0c44983206c3099f9d3ee35fc6d350', created_at=datetime.datetime(2022, 3, 2, 23, 29, 5, tzinfo=datetime.timezone.utc), last_modified=datetime.datetime(2021, 11, 18, 13, 37, 56, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=None, downloads=0, likes=0, library_name=None, tags=['PyTorch', 'Transformers', 'gpt2', 'squad', 'lm-head', 'casual-lm', 'text2text-generation', 'ru', 'en', 'region:us'], pipeline_tag='text2text-generation', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, siblings=[RepoSibling(rfilename='.gitattributes', size=None, blob_id=None, lfs=None), RepoSibling(rfilename='README.md', size=None, blob_id=None, lfs=None), RepoSibling(rfilename='deepspeed_config.json', size=None, blob_id=None, lfs=None), RepoSibling(rfilename='merges.txt', size=None, blob_id=None, lfs=None), RepoSibling(rfilename='mp_rank_00_model_states.pt', size=None, blob_id=None, lfs=None), RepoSibling(rfilename='vocab.json', size=None, blob_id=None, lfs=None)], spaces=None, safetensors=None)

# %%
# Get the public list of all dattasets
dataset_list = hf_api.list_datasets()

# %%
import pandas as pd
dataset_df = pd.DataFrame(dataset_list)

dataset_df.to_csv("datasets.csv")
dataset_df.to_pickle("datasets.pkl")

# %%
dataset_df
# Out:
#                                             id        author  \
# 0                       acronym_identification          None
# 1                                ade_corpus_v2          None
# 2                        UCLNLP/adversarial_qa        UCLNLP
# 3                                        aeslc          None
# 4                         afrikaans_ner_corpus          None
# ...                                        ...           ...
# 135722                       autogenCTF/CTFAIA    autogenCTF
# 135723      tarun96/twitter_dataset_1713337115       tarun96
# 135724             sidd21sharma/chatBotdataset  sidd21sharma
# 135725  heliosprime/twitter_dataset_1713337286   heliosprime
# 135726  heliosprime/twitter_dataset_1713337292   heliosprime
#
#                                              sha                created_at  \
# 0       15ef643450d589d5883e289ffadeb03563e80a9e 2022-03-02 23:29:22+00:00
# 1       4ba01c71687dd7c996597042449448ea312126cf 2022-03-02 23:29:22+00:00
# 2       c2d5f738db1ad21a4126a144dfbb00cb51e0a4a9 2022-03-02 23:29:22+00:00
# 3       2305f2e63b68056f9b9037a3805c8c196e0d5581 2022-03-02 23:29:22+00:00
# 4       445834a997dce8b40e1d108638064381de80c497 2022-03-02 23:29:22+00:00
# ...                                          ...                       ...
# 135722  5b970e44826a69f2523df2a1c301daf47f134555 2024-04-17 06:58:12+00:00
# 135723  7b68e0309749bf27f3b41b651df11f98d3aa9ced 2024-04-17 06:58:36+00:00
# 135724  f59c1deaf71e486bf776be66e7f59d2ab750a105 2024-04-17 06:59:15+00:00
# 135725  c16a3cdd3469283973345732e3c13511b3645e2a 2024-04-17 07:01:26+00:00
# 135726  fe038ea16c633f1589a5aac5896dcbb3c4278225 2024-04-17 07:01:32+00:00
#
#                    last_modified  private  gated  disabled  downloads  likes  \
# 0      2024-01-09 11:39:57+00:00    False  False     False        899     18
# 1      2024-01-09 11:42:58+00:00    False  False     False       2268     23
# 2      2023-12-21 14:20:00+00:00    False  False     False        576     32
# 3      2024-01-09 11:49:13+00:00    False  False     False       3310     10
# 4      2024-01-09 11:51:47+00:00    False  False     False        400      4
# ...                          ...      ...    ...       ...        ...    ...
# 135722 2024-04-17 06:58:41+00:00    False  False     False          0      0
# 135723 2024-04-17 06:59:33+00:00    False  False     False          0      0
# 135724 2024-04-17 07:01:43+00:00    False  False     False          0      0
# 135725 2024-04-17 07:02:04+00:00    False  False     False          0      0
# 135726 2024-04-17 07:02:05+00:00    False  False     False          0      0
#
#              paperswithcode_id  \
# 0       acronym-identification
# 1                         None
# 2                adversarialqa
# 3                        aeslc
# 4                         None
# ...                        ...
# 135722                    None
# 135723                    None
# 135724                    None
# 135725                    None
# 135726                    None
#
#                                                      tags card_data siblings
# 0       [task_categories:token-classification, annotat...      None     None
# 1       [task_categories:text-classification, task_cat...      None     None
# 2       [task_categories:question-answering, task_ids:...      None     None
# 3       [task_categories:summarization, annotations_cr...      None     None
# 4       [task_categories:token-classification, task_id...      None     None
# ...                                                   ...       ...      ...
# 135722                                        [region:us]      None     None
# 135723                             [croissant, region:us]      None     None
# 135724                        [license:llama2, region:us]      None     None
# 135725                                        [region:us]      None     None
# 135726                                        [region:us]      None     None
#
# [135727 rows x 14 columns]
